# %%
# Import Library
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('Data.csv')
data
# Out:
#    Components   Runs   Result
# 0         C6+  Run 1   0.0323
# 1         C6+  Run 2   0.0346
# 2         C6+  Run 3   0.0346
# 3         C6+  Run 4   0.0343
# 4         C6+  Run 5   0.0338
# 5     Propane  Run 1   1.0037
# 6     Propane  Run 2   1.0074
# 7     Propane  Run 3   1.0095
# 8     Propane  Run 4   1.0115
# 9     Propane  Run 5   1.0138
# 10   i-Butane  Run 1   0.2962
# 11   i-Butane  Run 2   0.2983
# 12   i-Butane  Run 3   0.2990
# 13   i-Butane  Run 4   0.2999
# 14   i-Butane  Run 5   0.3009
# 15   n-Butane  Run 1   0.3032
# 16   n-Butane  Run 2   0.3055
# 17   n-Butane  Run 3   0.3071
# 18   n-Butane  Run 4   0.3089
# 19   n-Butane  Run 5   0.3105
# 20  i-Pentane  Run 1   0.1031
# 21  i-Pentane  Run 2   0.1048
# 22  i-Pentane  Run 3   0.1058
# 23  i-Pentane  Run 4   0.1064
# 24  i-Pentane  Run 5   0.1072
# 25  n-Pentane  Run 1   0.1030
# 26  n-Pentane  Run 2   0.1056
# 27  n-Pentane  Run 3   0.1076
# 28  n-Pentane  Run 4   0.1086
# 29  n-Pentane  Run 5   0.1104
# ...

# %%
sns.boxplot(data, x = "Components", y = "Result")
# Out:
# <Axes: xlabel='Components', ylabel='Result'>
